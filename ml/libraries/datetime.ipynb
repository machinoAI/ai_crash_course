# %%
from datetime import date, datetime, timedelta
import time

# %%
today = date.today()
today
# Out:
# datetime.date(2026, 7, 17)

# %%
current_time = datetime.now()
current_time
# Out:
# datetime.datetime(2026, 7, 17, 20, 39, 52, 849356)

# %%
d = date(2026, 7,20)
dt = datetime(2026,7,20,8,12,20)
d
# Out:
# datetime.date(2026, 7, 20)

# %%
dt
# Out:
# datetime.datetime(2026, 7, 20, 8, 12, 20)

# %%
s = "2026-07-17"
d = datetime.strptime(s, "%Y-%m-%d")
d
# Out:
# datetime.datetime(2026, 7, 17, 0, 0)

# %%
now = datetime.now()
s = now.strftime("%d-%m-%Y-%H-%M-%S")
s
# Out:
# '17-07-2026-20-39-52'

# %%
today = date.today()
bdy = today+timedelta(days=20)
bdy
# Out:
# datetime.date(2026, 8, 6)

# %%
pdy = today-timedelta(days=20)
pdy
# Out:
# datetime.date(2026, 6, 27)

# %%
d1 = date(2026,12,18)
d2 = date(2026,11,9)
diff = d1 - d2
diff
# Out:
# datetime.timedelta(days=39)

# %%
now =datetime.now()
print(now.year)
print(now.month)
print(now.day)
print(now.hour)
print(now.minute)
print(now.second)
# Out:
# 2026
# 7
# 17
# 20
# 39
# 52

# %%
print(now.weekday())
# Out:
# 4

# %%
d1 = date(2026,12,18)
d2 = date(2026,11,9)
diff = d1 > d2
diff
# Out:
# True

# %%
diff = d1 < d2
diff
# Out:
# False

# %%
diff = d2 == d1
diff
# Out:
# False

# %%
diff = d2 = d1
diff
# Out:
# datetime.date(2026, 12, 18)

# %%
d1 = datetime.now()
ts = d1.timestamp() #millis
ts
# Out:
# 1784300992.915816

# %%
dt = datetime.fromtimestamp(ts)
dt
# Out:
# datetime.datetime(2026, 7, 17, 20, 39, 52, 915816)

# %%
arr = ["a", "b", "c"]

s = "".join(arr)
s
# Out:
# 'abc'

# %%
#Add 30 days to a date.
