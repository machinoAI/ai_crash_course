# %%
import pandas as pd

# %%
# create dataframe
sample_data = pd.DataFrame([1,2,3,4], columns=["ink_count"])
sample_data
# Out:
#    ink_count
# 0          1
# 1          2
# 2          3
# 3          4

# %%
sample_data.reset_index(drop=True)
# Out:
#    ink_count
# 0          1
# 1          2
# 2          3
# 3          4

# %%
# Load data
data = pd.read_csv("/Users/raviranjan/Documents/personal/ai_crash_course/data/housing_price_data_set.csv")

# %%
data = data.drop(columns = ["Unnamed: 0"])
data
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# ...

# %%
#check head
data.head()
# Out:
#      price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0  42000.0     5850         3        1        2      yes      no      yes
# 1  38500.0     4000         2        1        1      yes      no       no
# 2  49500.0     3060         3        1        1      yes      no       no
# 3  60500.0     6650         3        1        2      yes     yes       no
# 4  61000.0     6360         2        1        1      yes      no       no
#
#   gashw airco  garagepl prefarea
# 0    no    no         1       no
# 1    no    no         0       no
# 2    no    no         0       no
# 3    no    no         0       no
# 4    no    no         0       no

# %%
#check tail
data.tail()
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# 541    no   yes         0       no
# 542    no   yes         0       no
# 543    no   yes         1       no
# 544    no   yes         1       no
# 545    no   yes         1       no

# %%
#check shape
data.shape
# Out:
# (546, 12)

# %%
#check columns
data.columns
# Out:
# Index(['price', 'lotsize', 'bedrooms', 'bathrms', 'stories', 'driveway',
#        'recroom', 'fullbase', 'gashw', 'airco', 'garagepl', 'prefarea'],
#       dtype='object')

# %%
len(data.columns)
# Out:
# 12

# %%
#check datatypes
data.dtypes
# Out:
# price       float64
# lotsize       int64
# bedrooms      int64
# bathrms       int64
# stories       int64
# driveway     object
# recroom      object
# fullbase     object
# gashw        object
# airco        object
# garagepl      int64
# prefarea     object
# dtype: object

# %%
data.

# %%
# check info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546 entries, 0 to 545
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   price     546 non-null    float64
#  1   lotsize   546 non-null    int64
#  2   bedrooms  546 non-null    int64
#  3   bathrms   546 non-null    int64
#  4   stories   546 non-null    int64
#  5   driveway  546 non-null    object
#  6   recroom   546 non-null    object
#  7   fullbase  546 non-null    object
#  8   gashw     546 non-null    object
#  9   airco     546 non-null    object
#  10  garagepl  546 non-null    int64
#  11  prefarea  546 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 51.3+ KB

# %%
# df.describe()
data.describe()
# Out:
#                price       lotsize    bedrooms     bathrms     stories  \
# count     546.000000    546.000000  546.000000  546.000000  546.000000
# mean    68121.597070   5150.265568    2.965201    1.285714    1.807692
# std     26702.670926   2168.158725    0.737388    0.502158    0.868203
# min     25000.000000   1650.000000    1.000000    1.000000    1.000000
# 25%     49125.000000   3600.000000    2.000000    1.000000    1.000000
# 50%     62000.000000   4600.000000    3.000000    1.000000    2.000000
# 75%     82000.000000   6360.000000    3.000000    2.000000    2.000000
# max    190000.000000  16200.000000    6.000000    4.000000    4.000000
#
#          garagepl
# count  546.000000
# mean     0.692308
# std      0.861307
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
# Select 1 columns
data["driveway"]
# Out:
# 0      yes
# 1      yes
# 2      yes
# 3      yes
# 4      yes
#       ...
# 541    yes
# 542    yes
# 543    yes
# 544    yes
# 545    yes
# Name: driveway, Length: 546, dtype: object

# %%
# Selct multiple columns
data[["driveway", "recroom"]]
# Out:
#     driveway recroom
# 0        yes      no
# 1        yes      no
# 2        yes      no
# 3        yes     yes
# 4        yes      no
# ..       ...     ...
# 541      yes     yes
# 542      yes      no
# 543      yes     yes
# 544      yes     yes
# 545      yes      no
#
# [546 rows x 2 columns]

# %%
# Select by integer position
data.iloc[1:4]
# Out:
#      price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 1  38500.0     4000         2        1        1      yes      no       no
# 2  49500.0     3060         3        1        1      yes      no       no
# 3  60500.0     6650         3        1        2      yes     yes       no
#
#   gashw airco  garagepl prefarea
# 1    no    no         0       no
# 2    no    no         0       no
# 3    no    no         0       no

# %% [raw]
# # select by label
# data.loc[5, "driveway"]

# %%
#filter rows
data[data["bedrooms"]>4]
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 43    92000.0     8580         5        3        2      yes      no       no
# 50    55000.0     5300         5        2        2      yes      no       no
# 119  116000.0     6840         5        1        2      yes     yes      yes
# 148   80000.0     4800         5        2        3       no      no      yes
# 158   62000.0     1905         5        1        2       no      no      yes
# 184   28000.0     3420         5        1        2       no      no       no
# 201   53900.0     2520         5        2        1       no      no      yes
# 237   50000.0     3600         6        1        2      yes      no       no
# 354   86900.0     4300         6        2        2      yes      no       no
# 367  120000.0     7950         5        2        2      yes      no      yes
# 368  145000.0    16200         5        3        2      yes      no       no
# ...

# %%
# Filter using AND
data[(data.bedrooms>4) & (data.prefarea=='yes')]
# Out:
#        price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 456  79500.0     5400         5        1        2      yes     yes      yes
#
#     gashw airco  garagepl prefarea
# 456    no   yes         0      yes

# %%
# Filter using OR
data[(data.bedrooms>4) | (data.prefarea=='yes')]
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 43    92000.0     8580         5        3        2      yes      no       no
# 50    55000.0     5300         5        2        2      yes      no       no
# 119  116000.0     6840         5        1        2      yes     yes      yes
# 148   80000.0     4800         5        2        3       no      no      yes
# 158   62000.0     1905         5        1        2       no      no      yes
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 481   95000.0     5700         3        1        1      yes     yes      yes
# 482   95500.0     6600         2        2        4      yes      no      yes
# 483   51500.0     4000         2        1        1      yes      no       no
# 484   62900.0     4880         3        1        1      yes      no       no
# 485  118500.0     4880         4        2        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# ...

# %%
# Negate condition
data[~(data.prefarea=='yes')]
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# ...

# %%
# Cleaner filtering
data.query("bedrooms==4")
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 17    40750.0     5200         4        1        3      yes      no       no
# 21    65900.0     4510         4        2        2      yes      no      yes
# 31    48000.0     3500         4        1        2      yes      no       no
# 38    82000.0     5400         4        2        2      yes      no       no
# 42    82000.0     4640         4        1        2      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 521  105000.0     6000         4        2        4      yes     yes       no
# 522  108000.0     6000         4        2        4      yes      no       no
# 523  110000.0     6000         4        2        4      yes      no       no
# 524  113000.0     6000         4        2        4      yes      no       no
# 539   85000.0     7320         4        2        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# ...

# %%
# unique()
data.recroom.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
# nunique() count values
data.recroom.nunique()
# Out:
# 2

# %%
# Frequency of each value
data["bedrooms"].value_counts()
# Out:
# bedrooms
# 3    301
# 2    136
# 4     95
# 5     10
# 1      2
# 6      2
# Name: count, dtype: int64

# %%
#find missing values
data.isna()
# Out:
#      price  lotsize  bedrooms  bathrms  stories  driveway  recroom  fullbase  \
# 0    False    False     False    False    False     False    False     False
# 1    False    False     False    False    False     False    False     False
# 2    False    False     False    False    False     False    False     False
# 3    False    False     False    False    False     False    False     False
# 4    False    False     False    False    False     False    False     False
# ..     ...      ...       ...      ...      ...       ...      ...       ...
# 541  False    False     False    False    False     False    False     False
# 542  False    False     False    False    False     False    False     False
# 543  False    False     False    False    False     False    False     False
# 544  False    False     False    False    False     False    False     False
# 545  False    False     False    False    False     False    False     False
#
#      gashw  airco  garagepl  prefarea
# ...

# %%
# count missing values
data.isna().sum()
# Out:
# price       0
# lotsize     0
# bedrooms    0
# bathrms     0
# stories     0
# driveway    0
# recroom     0
# fullbase    0
# gashw       0
# airco       0
# garagepl    0
# prefarea    0
# dtype: int64

# %%
# Non- missing values
data.notna()
# Out:
#      price  lotsize  bedrooms  bathrms  stories  driveway  recroom  fullbase  \
# 0     True     True      True     True     True      True     True      True
# 1     True     True      True     True     True      True     True      True
# 2     True     True      True     True     True      True     True      True
# 3     True     True      True     True     True      True     True      True
# 4     True     True      True     True     True      True     True      True
# ..     ...      ...       ...      ...      ...       ...      ...       ...
# 541   True     True      True     True     True      True     True      True
# 542   True     True      True     True     True      True     True      True
# 543   True     True      True     True     True      True     True      True
# 544   True     True      True     True     True      True     True      True
# 545   True     True      True     True     True      True     True      True
#
#      gashw  airco  garagepl  prefarea
# ...

# %%
# Remove row with missing values
data.dropna()
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# ...

# %%
# Remove row with specific columns
data.dropna(subset=["prefarea"])
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# ...

# %%
data["member_allowed"] = None

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546 entries, 0 to 545
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   price           546 non-null    float64
#  1   lotsize         546 non-null    int64
#  2   bedrooms        546 non-null    int64
#  3   bathrms         546 non-null    int64
#  4   stories         546 non-null    int64
#  5   driveway        546 non-null    object
#  6   recroom         546 non-null    object
#  7   fullbase        546 non-null    object
#  8   gashw           546 non-null    object
#  9   airco           546 non-null    object
#  10  garagepl        546 non-null    int64
#  11  prefarea        546 non-null    object
#  12  member_allowed  0 non-null      object
# dtypes: float64(1), int64(5), object(7)
# memory usage: 55.6+ KB

# %%
# Fill missing values
data["member_allowed"]= data["member_allowed"].fillna(5)?
# Out:
# /var/folders/17/35md0zr16hvdjvkw_fln7jxw0000gn/T/ipykernel_63474/2752606058.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data["member_allowed"]= data["member_allowed"].fillna(5)

# %%
# Impute with mean
data["member_allowed"].fillna(data["bedrooms"].mean())

# %%
# Impute with median
data["member_allowed"].fillna(data["bedrooms"].median())
# Out:
# /var/folders/17/35md0zr16hvdjvkw_fln7jxw0000gn/T/ipykernel_63474/3089189853.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data["member_allowed"].fillna(data["bedrooms"].median())
# 0      3.0
# 1      3.0
# 2      3.0
# 3      3.0
# 4      3.0
#       ...
# 541    3.0
# 542    3.0
# 543    3.0
# 544    3.0
# 545    3.0
# Name: member_allowed, Length: 546, dtype: float64

# %%
# Remove duplicate rows
data.drop_duplicates()
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
# ...

# %%
# Remove duplicate columns
data.drop_duplicates("member_allowed")
# Out:
#      price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0  42000.0     5850         3        1        2      yes      no      yes
#
#   gashw airco  garagepl prefarea  member_allowed
# 0    no    no         1       no               5

# %%
data
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
# ...

# %%
#Sort asscending
data.sort_values("bedrooms")
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 18    45000.0     3450         1        1        1      yes      no       no
# 233   32500.0     3970         1        1        1       no      no       no
# 105   43000.0     4600         2        1        1      yes      no       no
# 106   48000.0     3720         2        1        1       no      no       no
# 245   37200.0     2910         2        1        1       no      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 119  116000.0     6840         5        1        2      yes     yes      yes
# 50    55000.0     5300         5        2        2      yes      no       no
# 158   62000.0     1905         5        1        2       no      no      yes
# 354   86900.0     4300         6        2        2      yes      no       no
# 237   50000.0     3600         6        1        2      yes      no       no
#
# ...

# %%
#Sort descending
data.sort_values("bedrooms", ascending=False)
# Out:
#        price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 237  50000.0     3600         6        1        2      yes      no       no
# 354  86900.0     4300         6        2        2      yes      no       no
# 148  80000.0     4800         5        2        3       no      no      yes
# 456  79500.0     5400         5        1        2      yes     yes      yes
# 50   55000.0     5300         5        2        2      yes      no       no
# ..       ...      ...       ...      ...      ...      ...     ...      ...
# 444  72500.0     5720         2        1        2      yes      no       no
# 98   35000.0     3500         2        1        1      yes     yes       no
# 234  36000.0     3000         2        1        2      yes      no       no
# 233  32500.0     3970         1        1        1       no      no       no
# 18   45000.0     3450         1        1        1      yes      no       no
#
#     gashw airco  garagepl prefarea  member_allowed
# ...

# %%
# Sort by multi-columns
data.sort_values(["bedrooms", "price"])
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 233   32500.0     3970         1        1        1       no      no       no
# 18    45000.0     3450         1        1        1      yes      no       no
# 55    25000.0     3620         2        1        1      yes      no       no
# 238   26000.0     3000         2        1        1      yes      no      yes
# 138   26500.0     2990         2        1        1       no      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 119  116000.0     6840         5        1        2      yes     yes      yes
# 367  120000.0     7950         5        2        2      yes      no      yes
# 368  145000.0    16200         5        3        2      yes      no       no
# 237   50000.0     3600         6        1        2      yes      no       no
# 354   86900.0     4300         6        2        2      yes      no       no
#
# ...

# %%
# Rename a column
data.rename(columns ={"member_allowed":"members_count"}, inplace=True)

# %%
#Remove a column
data.drop(columns =["members_count"])
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# ...

# %%
# Apply a function
data["members_count"] = data["bedrooms"].apply(lambda x: x+1)

# %%
# Map individual values
data["prefarea"].map({"yes":1, "no":0})
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 541    0
# 542    0
# 543    0
# 544    0
# 545    0
# Name: prefarea, Length: 546, dtype: int64

# %%
#Replace values
data["prefarea"].replace({"yes":1, "no":0})
# Out:
# /var/folders/17/35md0zr16hvdjvkw_fln7jxw0000gn/T/ipykernel_63474/3809758391.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data["prefarea"].replace({"yes":1, "no":0})
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 541    0
# 542    0
# 543    0
# 544    0
# 545    0
# Name: prefarea, Length: 546, dtype: int64

# %%
# Change data types
data["bedrooms"].astype("float")
# Out:
# 0      3.0
# 1      2.0
# 2      3.0
# 3      3.0
# 4      2.0
#       ...
# 541    3.0
# 542    3.0
# 543    3.0
# 544    3.0
# 545    3.0
# Name: bedrooms, Length: 546, dtype: float64

# %%
# Aggregate by groups
data.groupby("prefarea")["price"].count()
# Out:
# prefarea
# no     418
# yes    128
# Name: price, dtype: int64

# %%
#sum by groups
data.groupby("prefarea")["price"].sum()
# Out:
# prefarea
# no     26444137.0
# yes    10750255.0
# Name: price, dtype: float64

# %%
#Mean by groups
data.groupby("prefarea")["price"].mean()
# Out:
# prefarea
# no     63263.485646
# yes    83986.367188
# Name: price, dtype: float64

# %%
#Count by records by group
data.groupby("prefarea")["price"].count()
# Out:
# prefarea
# no     418
# yes    128
# Name: price, dtype: int64

# %%
#Multiple Aggregtion
aggregated_data = data.groupby("prefarea")["price"].agg(["mean", "max", "min", "count"])

# %%
aggregated_data.reset_index()
# Out:
#   prefarea          mean       max      min  count
# 0       no  63263.485646  175000.0  25000.0    418
# 1      yes  83986.367188  190000.0  31900.0    128

# %%
# Number of rows per group
data["prefarea"].size
# Out:
# 546

# %% [markdown]
# | Pandas formula                         | Example                                                     | When to use                          |
# | -------------------------------------- | ----------------------------------------------------------- | ------------------------------------ |
# | `pd.DataFrame()`                       | `pd.DataFrame({"A":[1,2]})`                                 | Create a DataFrame                   |
# | `df.head(n)`                           | `df.head(5)`                                                | View first rows                      |
# | `df.tail(n)`                           | `df.tail(5)`                                                | View last rows                       |
# | `df.shape`                             | `df.shape` → `(100, 5)`                                     | Get rows and columns                 |
# | `df.columns`                           | `df.columns`                                                | Get column names                     |
# | `df.dtypes`                            | `df.dtypes`                                                 | Check data types                     |
# | `df.info()`                            | `df.info()`                                                 | Inspect columns, types, nulls        |
# | `df.describe()`                        | `df.describe()`                                             | Summary statistics                   |
# | `df["col"]`                            | `df["age"]`                                                 | Select one column                    |
# | `df[["c1","c2"]]`                      | `df[["age","salary"]]`                                      | Select multiple columns              |
# | `df.iloc[]`                            | `df.iloc[0, 2]`                                             | Select by integer position           |
# | `df.loc[]`                             | `df.loc[5, "salary"]`                                       | Select by label                      |
# | `df[df["age"] > 30]`                   | `df[df["age"] > 30]`                                        | Filter rows                          |
# | `df[(c1) & (c2)]`                      | `df[(df.age>30) & (df.salary>50000)]`                       | Filter using AND                     |
# | `df[(c1) \| (c2)]`                     | `df[(df.age<20) \| (df.age>60)]`                            | Filter using OR                      |
# | `~condition`                           | `df[~(df["city"]=="Delhi")]`                                | Negate a condition                   |
# | `df.query()`                           | `df.query("age > 30")`                                      | Cleaner filtering                    |
# | `df["col"].unique()`                   | `df["city"].unique()`                                       | Find unique values                   |
# | `df["col"].nunique()`                  | `df["user_id"].nunique()`                                   | Count unique values                  |
# | `df["col"].value_counts()`             | `df["city"].value_counts()`                                 | Frequency of each value              |
# | `df.isna()`                            | `df.isna()`                                                 | Find missing values                  |
# | `df.isna().sum()`                      | `df.isna().sum()`                                           | Count missing values                 |
# | `df.notna()`                           | `df["age"].notna()`                                         | Find non-missing values              |
# | `df.dropna()`                          | `df.dropna()`                                               | Remove rows with missing values      |
# | `df.dropna(subset=[])`                 | `df.dropna(subset=["age"])`                                 | Remove rows missing specific columns |
# | `df.fillna()`                          | `df["age"].fillna(30)`                                      | Fill missing values                  |
# | `df["col"].fillna(df["col"].mean())`   | `df["age"].fillna(df["age"].mean())`                        | Impute with mean                     |
# | `df["col"].fillna(df["col"].median())` | `df["age"].fillna(df["age"].median())`                      | Impute with median                   |
# | `df.drop_duplicates()`                 | `df.drop_duplicates()`                                      | Remove duplicate rows                |
# | `df.drop_duplicates("col")`            | `df.drop_duplicates("user_id")`                             | Remove duplicates based on column    |
# | `df.sort_values()`                     | `df.sort_values("salary")`                                  | Sort ascending                       |
# | `df.sort_values(..., ascending=False)` | `df.sort_values("salary", ascending=False)`                 | Sort descending                      |
# | `df.sort_values(["c1","c2"])`          | `df.sort_values(["dept","salary"])`                         | Sort by multiple columns             |
# | `df["new"] = ...`                      | `df["annual"] = df["monthly"]*12`                           | Create a column                      |
# | `df.rename()`                          | `df.rename(columns={"old":"new"})`                          | Rename columns                       |
# | `df.drop(columns=[])`                  | `df.drop(columns=["age"])`                                  | Remove columns                       |
# | `df["col"].apply()`                    | `df["age"].apply(lambda x:x+1)`                             | Apply a function                     |
# | `df["col"].map()`                      | `df["gender"].map({"M":1,"F":0})`                           | Map individual values                |
# | `df.replace()`                         | `df["gender"].replace({"M":1,"F":0})`                       | Replace values                       |
# | `df.astype()`                          | `df["age"].astype(int)`                                     | Change data type                     |
# | `df.groupby()`                         | `df.groupby("city")["salary"].mean()`                       | Aggregate by groups                  |
# | `df.groupby().sum()`                   | `df.groupby("dept")["sales"].sum()`                         | Sum by group                         |
# | `df.groupby().mean()`                  | `df.groupby("dept")["salary"].mean()`                       | Mean by group                        |
# | `df.groupby().count()`                 | `df.groupby("dept")["id"].count()`                          | Count records per group              |
# | `df.groupby().agg()`                   | `df.groupby("dept")["salary"].agg(["mean","max","min"])`    | Multiple aggregations                |
# | `df.groupby().size()`                  | `df.groupby("dept").size()`                                 | Number of rows per group             |
# | `df["col"].sum()`                      | `df["revenue"].sum()`                                       | Total                                |
# | `df["col"].mean()`                     | `df["salary"].mean()`                                       | Average                              |
# | `df["col"].median()`                   | `df["salary"].median()`                                     | Median                               |
# | `df["col"].std()`                      | `df["salary"].std()`                                        | Standard deviation                   |
# | `df["col"].min()`                      | `df["salary"].min()`                                        | Minimum                              |
# | `df["col"].max()`                      | `df["salary"].max()`                                        | Maximum                              |
# | `df["col"].quantile()`                 | `df["salary"].quantile(.95)`                                | Percentile                           |
# | `df.corr()`                            | `df[["age","salary"]].corr()`                               | Correlation                          |
# | `df["col"].rank()`                     | `df["salary"].rank(ascending=False)`                        | Rank values                          |
# | `pd.merge()`                           | `pd.merge(df1,df2,on="user_id")`                            | Join two DataFrames                  |
# | `pd.merge(..., how="left")`            | `pd.merge(df1,df2,on="id",how="left")`                      | Left join                            |
# | `pd.merge(..., how="inner")`           | `pd.merge(df1,df2,on="id",how="inner")`                     | Inner join                           |
# | `pd.concat()`                          | `pd.concat([df1,df2])`                                      | Combine DataFrames                   |
# | `pd.concat(..., axis=1)`               | `pd.concat([df1,df2],axis=1)`                               | Combine columns                      |
# | `df.pivot_table()`                     | `df.pivot_table(values="sales",index="city",aggfunc="sum")` | Reshape + aggregate                  |
# | `df["col"].str.lower()`                | `df["name"].str.lower()`                                    | Convert strings to lowercase         |
# | `df["col"].str.upper()`                | `df["name"].str.upper()`                                    | Convert strings to uppercase         |
# | `df["col"].str.contains()`             | `df[df["name"].str.contains("raj")]`                        | Search within strings                |
# | `df["col"].str.startswith()`           | `df[df["name"].str.startswith("A")]`                        | Filter by prefix                     |
# | `df["col"].str.split()`                | `df["name"].str.split(" ")`                                 | Split strings                        |
# | `pd.to_datetime()`                     | `df["date"]=pd.to_datetime(df["date"])`                     | Convert to datetime                  |
# | `df["date"].dt.year`                   | `df["date"].dt.year`                                        | Extract year                         |
# | `df["date"].dt.month`                  | `df["date"].dt.month`                                       | Extract month                        |
# | `df["date"].dt.day`                    | `df["date"].dt.day`                                         | Extract day                          |
# | `df["date"].dt.dayofweek`              | `df["date"].dt.dayofweek`                                   | Get weekday                          |
# | `df.shift()`                           | `df["sales"].shift(1)`                                      | Previous/next row comparison         |
# | `df.diff()`                            | `df["sales"].diff()`                                        | Difference between rows              |
# | `df.cumsum()`                          | `df["sales"].cumsum()`                                      | Cumulative sum                       |
# | `df.pct_change()`                      | `df["sales"].pct_change()`                                  | Percentage change                    |
# | `df.reset_index()`                     | `df.reset_index(drop=True)`                                 | Reset index                          |
# | `df.set_index()`                       | `df.set_index("user_id")`                                   | Set a column as index                |
# | `df.sample()`                          | `df.sample(100)`                                            | Randomly sample rows                 |
# | `df.nlargest()`                        | `df.nlargest(5,"salary")`                                   | Top N rows                           |
# | `df.nsmallest()`                       | `df.nsmallest(5,"salary")`                                  | Bottom N rows                        |

# %%
# Sum Total
data["price"].sum()
# Out:
# np.float64(37194392.0)

# %%
# Averagge

# %%
# Median

# %%
# Maximum

# %%
#Minimum

# %%
# Percentile

# %%
# Standard Deviation

# %%
# Correlation

# %%
# Rank values

# %%
# Join to df

# %%
#Left Join

# %%
# Inner Join

# %%
# Combines Dataframe

# %%
# Combine column

# %%
# Reshape + Aggregate

# %%
# Convert string to lowercase

# %%
# Convert string to uppercase

# %%
# Search within strings

# %%
# Filter by prefix

# %%
# Split string

# %%
# Conver to datetime

# %%
# Extract year

# %%
# Extract Month

# %%
# Extract day

# %%
# Extract wekday

# %%
# Previous/next row comparision

# %%
# Difference between rows

# %%
# Cummulative Sum

# %%
# Percentage change

# %%
#Reset Index

# %%
#Set a column as index

# %%
#Randomly Sample rows

# %%
# Top N rows

# %%
# Bottom N rows
